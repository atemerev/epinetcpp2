# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = [10, 7]

# %%
df = pd.read_csv("out.csv", header=None)
df
# Out:
#        0    1      2         3
# 0      2    0      1  0.999980
# 1      3    5      1  0.999930
# 2      4    2      6  0.999910
# 3      5    3      8  0.999880
# 4      6    4     11  0.999840
# ..   ...  ...    ...       ...
# 543  594  778  14796  0.187886
# 544  595  786  14790  0.187934
# 545  596  760  14741  0.188079
# 546  597  763  14712  0.188154
# 547  598  753  14674  0.188239
#
# [548 rows x 4 columns]

# %%
plt.figure()
plt.grid(True)
plt.title("Infection cases by day")
plt.xlabel("Time, days")
plt.ylabel("Cases count")
plt.plot(df[0], df[1])

# %%
plt.figure()
plt.grid(True)
plt.title("Total infected count")
plt.xlabel("Time, days")
plt.ylabel("Infected count")
plt.plot(df[0], df[2])

# %%
plt.figure()
plt.grid(True)
plt.title("Mean population susceptibility")
plt.xlabel("Time, days")
plt.ylabel("Mean susceptibility")
plt.plot(df[0], df[3])
