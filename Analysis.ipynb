# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = [15, 10]

# %%
df = pd.read_csv("out.csv", header=None)
df
# Out:
#        0    1
# 0      0    1
# 1      2    0
# 2      3    1
# 3      4    1
# 4      5    3
# ..   ...  ...
# 548  724  496
# 549  725  527
# 550  726  518
# 551  727  516
# 552  728  615
#
# [553 rows x 2 columns]

# %%
df[1]
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        3
#       ...
# 548    496
# 549    527
# 550    518
# 551    516
# 552    615
# Name: 1, Length: 553, dtype: int64

# %%
plt.figure()
plt.grid(True)
plt.plot(df[0], df[1])
