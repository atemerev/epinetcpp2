# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = [10, 7]

# %%
df = pd.read_csv("out.csv", header=None)
df
# Out:
#        0    1      2         3
# 0      1    0     10  0.999890
# 1      2   12     10  0.999770
# 2      3   14     22  0.999630
# 3      4   13     36  0.999500
# 4      5   20     49  0.999300
# ..   ...  ...    ...       ...
# 575  594  723  12775  0.207347
# 576  595  783  12891  0.207061
# 577  596  674  13044  0.207135
# 578  597  724  13087  0.207043
# 579  598  719  13146  0.207014
#
# [580 rows x 4 columns]

# %%
plt.figure()
plt.grid(True)
plt.title("Infection cases by day")
plt.xlabel("Time, days")
plt.ylabel("Cases count")
plt.plot(df[0], df[1])

# %%
plt.figure()
plt.grid(True)
plt.title("Total infected count")
plt.xlabel("Time, days")
plt.ylabel("Infected count")
plt.plot(df[0], df[2])

# %%
plt.figure()
plt.grid(True)
plt.title("Mean population susceptibility")
plt.xlabel("Time, days")
plt.ylabel("Mean susceptibility")
plt.plot(df[0], df[3])
