# %%
import pandas as pd
import matplotlib.pyplot as plt
import math

# %%
plt.rcParams['figure.figsize'] = [10, 7]

# %%
df = pd.read_csv("out.csv", header=None)
df
# Out:
#        0   1     2         3
# 0      4   0     3  0.999655
# 1      5   1     4  0.999537
# 2      6   2     6  0.999303
# 3      7   2     8  0.999075
# 4      8   1     9  0.998961
# ..   ...  ..   ...       ...
# 720  724  77  1582  0.218531
# 721  725  78  1598  0.218414
# 722  726  76  1573  0.218415
# 723  727  81  1565  0.218280
# 724  728  78  1548  0.217762
#
# [725 rows x 4 columns]

# %%
plt.figure()
plt.grid(True)
plt.title("Infection cases by day")
plt.xlabel("Time, days")
plt.ylabel("Cases count")
plt.plot(df[0], df[1])
plt.savefig("mine-cases.pdf")

# %%
plt.figure()
plt.grid(True)
plt.title("Total infected count")
plt.xlabel("Time, days")
plt.ylabel("Infected count")
plt.plot(df[0], df[2])
plt.savefig("mine-total.pdf")

# %%
plt.figure()
plt.grid(True)
plt.title("Mean population susceptibility")
plt.xlabel("Time, days")
plt.ylabel("Mean susceptibility")
plt.plot(df[0], df[3])

# %%
1 - math.exp(-200 / 200)
# Out:
# 0.6321205588285577
