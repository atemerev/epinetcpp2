# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = [15, 10]

# %%
df = pd.read_csv("out.csv", header=None)
df
# Out:
#        0    1
# 0      2    0
# 1      3    4
# 2      4    6
# 3      5    6
# 4      6   15
# ..   ...  ...
# 686  724  119
# 687  725   93
# 688  726  124
# 689  727  106
# 690  728  110
#
# [691 rows x 2 columns]

# %%
df[1]
# Out:
# 0        0
# 1        4
# 2        6
# 3        6
# 4       15
#       ...
# 686    119
# 687     93
# 688    124
# 689    106
# 690    110
# Name: 1, Length: 691, dtype: int64

# %%
plt.figure()
plt.grid(True)
plt.plot(df[1])
