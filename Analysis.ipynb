# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = [10, 7]

# %%
df = pd.read_csv("out.csv", header=None)
df
# Out:
#        0     1       2         3
# 0      0     1       0  0.999998
# 1      2     0       2  0.999997
# 2      3     2       2  0.999995
# 3      4     1       4  0.999994
# 4      5     3       5  0.999991
# ..   ...   ...     ...       ...
# 717  724  7981  149648  0.188276
# 718  725  7955  149972  0.188244
# 719  726  8045  150183  0.188199
# 720  727  8036  150328  0.188162
# 721  728  7999  150436  0.188171
#
# [722 rows x 4 columns]

# %%
df[1]
# Out:
# 0         1
# 1         0
# 2         2
# 3         1
# 4         3
#        ...
# 717    7981
# 718    7955
# 719    8045
# 720    8036
# 721    7999
# Name: 1, Length: 722, dtype: int64

# %%
plt.figure()
plt.grid(True)
plt.title("Infection cases by day")
plt.xlabel("Time, days")
plt.ylabel("Cases count")
plt.plot(df[0], df[1])

# %%
plt.figure()
plt.grid(True)
plt.title("Total infected count")
plt.xlabel("Time, days")
plt.ylabel("Infected count")
plt.plot(df[0], df[2])

# %%
plt.figure()
plt.grid(True)
plt.title("Mean population susceptibility")
plt.xlabel("Time, days")
plt.ylabel("Mean susceptibility")
plt.plot(df[0], df[3])
