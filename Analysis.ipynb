# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = [15, 10]

# %%
df = pd.read_csv("out.csv", header=None)
df
# Out:
#        0    1
# 0      2    0
# 1      4    0
# 2      5    1
# 3      6    4
# 4      7    3
# ..   ...  ...
# 703  724  806
# 704  725  747
# 705  726  768
# 706  727  778
# 707  728  824
#
# [708 rows x 2 columns]

# %%
df[1]
# Out:
# 0        0
# 1        0
# 2        1
# 3        4
# 4        3
#       ...
# 703    806
# 704    747
# 705    768
# 706    778
# 707    824
# Name: 1, Length: 708, dtype: int64

# %%
plt.figure()
plt.grid(True)
plt.plot(df[1])
