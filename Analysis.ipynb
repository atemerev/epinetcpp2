# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = [10, 7]

# %%
df = pd.read_csv("out.csv", header=None)
df
# Out:
#        0    1      2         3
# 0      1    0      1  0.999980
# 1      3    0      2  0.999970
# 2      4    2      2  0.999950
# 3      5    1      4  0.999940
# 4      6    2      5  0.999920
# ..   ...  ...    ...       ...
# 551  724  601  12522  0.243728
# 552  725  548  12405  0.243871
# 553  726  554  12220  0.243947
# 554  727  560  12058  0.244049
# 555  728  520  11842  0.244419
#
# [556 rows x 4 columns]

# %%
plt.figure()
plt.grid(True)
plt.title("Infection cases by day")
plt.xlabel("Time, days")
plt.ylabel("Cases count")
plt.plot(df[0], df[1])

# %%
plt.figure()
plt.grid(True)
plt.title("Total infected count")
plt.xlabel("Time, days")
plt.ylabel("Infected count")
plt.plot(df[0], df[2])

# %%
plt.figure()
plt.grid(True)
plt.title("Mean population susceptibility")
plt.xlabel("Time, days")
plt.ylabel("Mean susceptibility")
plt.plot(df[0], df[3])
