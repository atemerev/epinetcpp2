# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = [15, 10]

# %%
df = pd.read_csv("out.csv", header=None)
df
# Out:
#        0    1
# 0      2    0
# 1      3    3
# 2      4    2
# 3      5    3
# 4      6    6
# ..   ...  ...
# 693  724  387
# 694  725  406
# 695  726  388
# 696  727  399
# 697  728  426
#
# [698 rows x 2 columns]

# %%
df[1]
# Out:
# 0        0
# 1        3
# 2        2
# 3        3
# 4        6
#       ...
# 693    387
# 694    406
# 695    388
# 696    399
# 697    426
# Name: 1, Length: 698, dtype: int64

# %%
plt.figure()
plt.grid(True)
plt.plot(df[0], df[1])
