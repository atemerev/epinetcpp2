# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("out.csv")
df
# Out:
#        0    1
# 0      2    1
# 1      4    2
# 2      5    3
# 3      6    2
# 4      7    3
# ..   ...  ...
# 592  595  426
# 593  596  446
# 594  597  437
# 595  598  453
# 596  599  469
#
# [597 rows x 2 columns]

# %%
plt.plot(df['0'], df['1'])
