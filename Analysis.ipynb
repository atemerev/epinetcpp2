# %%
import pandas as pd
import matplotlib.pyplot as plt
import math

# %%
plt.rcParams['figure.figsize'] = [10, 7]

# %%
df = pd.read_csv("out.csv", header=None)
df
# Out:
#        0    1      2         3
# 0      2    0      2  0.699986
# 1      5    0      3  0.699979
# 2      7    0      4  0.699972
# 3      8    3      7  0.699951
# 4      9    4     11  0.699923
# ..   ...  ...    ...       ...
# 705  724  712  15378  0.309963
# 706  725  712  15308  0.308727
# 707  726  717  15199  0.307475
# 708  727  684  15091  0.306448
# 709  728  629  14909  0.305615
#
# [710 rows x 4 columns]

# %%
plt.figure()
plt.grid(True)
plt.title("Infection cases by day")
plt.xlabel("Time, days")
plt.ylabel("Cases count")
plt.plot(df[0], df[1])
plt.savefig("mine-cases.pdf")

# %%
plt.figure()
plt.grid(True)
plt.title("Total infected count")
plt.xlabel("Time, days")
plt.ylabel("Infected count")
plt.plot(df[0], df[2])
plt.savefig("mine-total.pdf")

# %%
plt.figure()
plt.grid(True)
plt.title("Mean population susceptibility")
plt.xlabel("Time, days")
plt.ylabel("Mean susceptibility")
plt.plot(df[0], df[3])

# %%
1 - math.exp(-200 / 200)
# Out:
# 0.6321205588285577
