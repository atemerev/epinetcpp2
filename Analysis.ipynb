# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = [15, 10]

# %%
df = pd.read_csv("out.csv", header=None)
df
# Out:
#        0    1
# 0      2    0
# 1      4    0
# 2      6    0
# 3      8    0
# 4      9    5
# ..   ...  ...
# 702  724  755
# 703  725  704
# 704  726  688
# 705  727  734
# 706  728  706
#
# [707 rows x 2 columns]

# %%
df[1]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        5
#       ...
# 702    755
# 703    704
# 704    688
# 705    734
# 706    706
# Name: 1, Length: 707, dtype: int64

# %%
plt.figure()
plt.grid(True)
plt.plot(df[0], df[1])
